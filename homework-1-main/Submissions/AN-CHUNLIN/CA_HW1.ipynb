# %% [markdown]
# ## Homework 1 | Chunlin An | ca2965
#
# # Project chosen: [**BossSensor**](https://github.com/Hironsan/BossSensor) by Hironsan
# ---
#
# ## Table of Contents (WIP)
# * [1. Project description](#bullet1)
#
#
# ---
# ### 1. Project description <a class="anchor" id="bullet1"></a>
#
# This project utilizes neural networks to train an algorithm that (with enough image input of boss) recognizes the boss's face as distinct from other faces. When the boss appears in the camera, the program fetches the image and automatically displays a PyCharm screenshot to hide other tabs on the screen. (I think it's hilarious)

# %% [markdown]
# ### 2. Sample images
